# %% [markdown]
# 1.Importing dataset from kaggle

# %%
import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'pins-face-recognition:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F543939%2F992580%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240508%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240508T140329Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,vgg-face-weights:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F1267072%2F2111872%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240508%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240508T140329Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading pins-face-recognition, 389784397 bytes compressed
# [==================================================] 389784397 bytes downloaded
# Downloaded and uncompressed: pins-face-recognition
# Downloading vgg-face-weights, 545997436 bytes compressed
# [==================================================] 545997436 bytes downloaded
# Downloaded and uncompressed: vgg-face-weights
# Data source import complete.

# %% [markdown]
# 2.Import the necessary libraries

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# used to supress display of warnings
import warnings

from sklearn.metrics import precision_recall_curve,accuracy_score,f1_score,precision_score,recall_score

# %% [markdown]
# #### Setting Options

# %%
# suppress display of warnings
warnings.filterwarnings('ignore')

# %%
import os
source_dir=os.path.join('/kaggle','input','pins-face-recognition','105_classes_pins_dataset')

# %% [markdown]
# 3.Load metadata

# %%
class IdentityMetadata():
    def __init__(self, base, name, file):
        self.base = base
        # identity name
        self.name = name
        # image file name
        self.file = file

    def __repr__(self):
        return self.image_path()

    def image_path(self):
        return os.path.join(self.base, self.name, self.file)

def load_metadata(path):
    metadata = []
    for i in os.listdir(path):
        for f in os.listdir(os.path.join(path, i)):
            # Check file extension. Allow only jpg/jpeg' files.
            ext = os.path.splitext(f)[1]
            if ext == '.jpg' or ext == '.jpeg':
                metadata.append(IdentityMetadata(path, i, f))
    return np.array(metadata)

# metadata = load_metadata('images')
metadata = load_metadata(source_dir)

# %%
print('metadata shape :', metadata.shape)
# Out:
# metadata shape : (17534,)

# %%
metadata[1500]
# Out:
# /kaggle/input/pins-face-recognition/105_classes_pins_dataset/pins_Tom Hiddleston/Tom Hiddleston127_1434.jpg

# %%
type(metadata[1500]), metadata[1500].image_path()
# Out:
# (__main__.IdentityMetadata,
#  '/kaggle/input/pins-face-recognition/105_classes_pins_dataset/pins_Tom Hiddleston/Tom Hiddleston127_1434.jpg')

# %% [markdown]
# 4. Define a function to load image from the metadata

# %%
import cv2
def load_image(path):
    img = cv2.imread(path, 1)

    return img[...,::-1]

# %% [markdown]
# <p style = "font-size:20px; color: #007580 "><strong> Load a sample image</strong></p>
# - Load one image using the function "load_image"

# %%
load_image('/kaggle/input/pins-face-recognition/105_classes_pins_dataset/pins_Emilia Clarke/Emilia Clarke247_998.jpg')
# Out:
# array([[[33, 36, 51],
#         [34, 37, 52],
#         [39, 43, 55],
#         ...,
#         [47, 40, 47],
#         [57, 50, 57],
#         [67, 60, 67]],
#
#        [[39, 42, 57],
#         [42, 45, 60],
#         [47, 51, 63],
#         ...,
#         [59, 52, 59],
#         [73, 66, 73],
#         [85, 78, 85]],
#
#        [[51, 55, 67],
#         [53, 57, 69],
#         [58, 62, 74],
#         ...,
#         [76, 69, 76],
#         [86, 79, 86],
#         [94, 87, 94]],
#
#        ...,
#
#        [[93, 42, 38],
#         [93, 42, 38],
#         [96, 45, 41],
#         ...,
#         [61, 35, 36],
#         [60, 34, 35],
#         [59, 33, 34]],
#
#        [[94, 44, 37],
#         [89, 39, 32],
#         [89, 39, 32],
#         ...,
#         [60, 34, 35],
#         [59, 33, 36],
#         [58, 32, 35]],
#
#        [[99, 49, 42],
#         [89, 39, 32],
#         [85, 35, 28],
#         ...,
#         [60, 34, 37],
#         [59, 33, 36],
#         [58, 32, 35]]], dtype=uint8)

# %% [markdown]
# <a id = '4.1'></a>
# <p style = "font-size:20px; color: #007580 "><strong> 5. VGG Face model </strong></p>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import ZeroPadding2D, Convolution2D, MaxPooling2D, Dropout, Flatten, Activation

def vgg_face():
    model = Sequential()
    model.add(ZeroPadding2D((1,1),input_shape=(224,224, 3)))
    model.add(Convolution2D(64, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(256, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(ZeroPadding2D((1,1)))
    model.add(Convolution2D(512, (3, 3), activation='relu'))
    model.add(MaxPooling2D((2,2), strides=(2,2)))

    model.add(Convolution2D(4096, (7, 7), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Convolution2D(4096, (1, 1), activation='relu'))
    model.add(Dropout(0.5))
    model.add(Convolution2D(2622, (1, 1)))
    model.add(Flatten())
    model.add(Activation('softmax'))
    return model

# %% [markdown]
# <p style = "font-size:20px; color: #007580 "><strong> 6.Load the model </strong></p>

# %%
model = vgg_face()

model.load_weights('../input/vgg-face-weights/vgg_face_weights.h5')

# %% [markdown]
# <p style = "font-size:20px; color: #007580 "><strong> 7.Get vgg_face_descriptor </strong></p>

# %%
model.layers[0], model.layers[-2]
# Out:
# (<keras.src.layers.reshaping.zero_padding2d.ZeroPadding2D at 0x7d39703f3400>,
#  <keras.src.layers.reshaping.flatten.Flatten at 0x7d39703f0970>)

# %%
from tensorflow.keras.models import Model
vgg_face_descriptor = Model(inputs=model.layers[0].input, outputs=model.layers[-2].output)

# %%
type(vgg_face_descriptor)
# Out:
# keras.src.engine.functional.Functional

# %%
vgg_face_descriptor.inputs, vgg_face_descriptor.outputs
# Out:
# ([<KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'zero_padding2d_input')>],
#  [<KerasTensor: shape=(None, 2622) dtype=float32 (created by layer 'flatten')>])

# %% [markdown]
# <a id = '4.2'></a>
# <p style = "font-size:20px; color: #007580 "><strong> Generate embeddings for each image in the dataset </strong></p>
#
# - Given below is an example to load the first image in the metadata and get its embedding vector from the pre-trained model.

# %%
# Get embedding vector for first image in the metadata using the pre-trained model
img_path = metadata[0].image_path()
img = load_image(img_path)

# Normalising pixel values from [0-255] to [0-1]: scale RGB values to interval [0,1]
img = (img / 255.).astype(np.float32)
img = cv2.resize(img, dsize = (224,224))
print(img.shape)

# Obtain embedding vector for an image
# Get the embedding vector for the above image using vgg_face_descriptor model and print the shape
embedding_vector = vgg_face_descriptor.predict(np.expand_dims(img, axis=0))[0]
print(embedding_vector.shape)
# Out:
# (224, 224, 3)
# 1/1 [==============================] - 2s 2s/step
# (2622,)

# %%
embedding_vector[0], type(embedding_vector), type(embedding_vector[0])
# Out:
# (0.019112924, numpy.ndarray, numpy.float32)

# %%
embedding_vector[2], embedding_vector[98], embedding_vector[-2]
# Out:
# (-0.0012275872, -0.00071738474, 0.017318413)

# %% [markdown]
# <p style = "font-size:20px; color: #007580 "><strong> Generate embeddings for all images </strong></p>
#
# - Write code to iterate through metadata and create embeddings for each image using `vgg_face_descriptor.predict()` and store in a list with name `embeddings`
#
# - If there is any error in reading any image in the dataset, fill the emebdding vector of that image with 2622-zeroes as the final embedding from the model is of length 2622.

# %%
total_images = len(metadata)

print('total_images :', total_images)
# Out:
# total_images : 17534

# %%
embeddings = np.zeros((metadata.shape[0], 2622))
for i, m in enumerate(metadata):
    img_path = metadata[i].image_path()
    img = load_image(img_path)
    img = (img / 255.).astype(np.float32)
    img = cv2.resize(img, dsize = (224,224))
    embedding_vector = vgg_face_descriptor.predict(np.expand_dims(img, axis=0))[0]
    embeddings[i]=embedding_vector
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 957ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 612ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 617ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 615ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 616ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 918ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 959ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 621ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 862ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 821ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 616ms/step
# 1/1 [==============================] - 1s 615ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 617ms/step
# 1/1 [==============================] - 1s 631ms/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 968ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 713ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 637ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 642ms/step
# 1/1 [==============================] - 1s 989ms/step
# 1/1 [==============================] - 1s 997ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 814ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 974ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 726ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 616ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 625ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 622ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 620ms/step
# 1/1 [==============================] - 1s 670ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 729ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 611ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 888ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 790ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 754ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 612ms/step
# 1/1 [==============================] - 1s 998ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 786ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 616ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 611ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 644ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 777ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 631ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 995ms/step
# 1/1 [==============================] - 1s 990ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 895ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 925ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 759ms/step
# 1/1 [==============================] - 1s 615ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 989ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 765ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 897ms/step
# 1/1 [==============================] - 1s 974ms/step
# 1/1 [==============================] - 1s 990ms/step
# 1/1 [==============================] - 1s 783ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 616ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 620ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 805ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 617ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 617ms/step
# 1/1 [==============================] - 1s 622ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 617ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 984ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 826ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 616ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 623ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 986ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 733ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 984ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 796ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 617ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 914ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 830ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 915ms/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 963ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 622ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 646ms/step
# 1/1 [==============================] - 1s 992ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 736ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 611ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 996ms/step
# 1/1 [==============================] - 1s 992ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 753ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 871ms/step
# 1/1 [==============================] - 1s 990ms/step
# 1/1 [==============================] - 1s 973ms/step
# 1/1 [==============================] - 1s 848ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 619ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 892ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 951ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 684ms/step
# 1/1 [==============================] - 1s 981ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 770ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 943ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 748ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 939ms/step
# 1/1 [==============================] - 1s 756ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 633ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 1s 975ms/step
# 1/1 [==============================] - 1s 992ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 760ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 612ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 830ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 822ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 860ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 736ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 988ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 620ms/step
# 1/1 [==============================] - 1s 620ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 636ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 816ms/step
# 1/1 [==============================] - 1s 988ms/step
# 1/1 [==============================] - 1s 915ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 746ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 678ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 955ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 696ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 617ms/step
# 1/1 [==============================] - 1s 618ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 620ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 996ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 840ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 611ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 954ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 803ms/step
# 1/1 [==============================] - 1s 615ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 974ms/step
# 1/1 [==============================] - 1s 990ms/step
# 1/1 [==============================] - 1s 984ms/step
# 1/1 [==============================] - 1s 777ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 963ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 729ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 899ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 752ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 974ms/step
# 1/1 [==============================] - 1s 972ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 760ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 947ms/step
# 1/1 [==============================] - 1s 996ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 796ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 611ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 946ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 934ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 576ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 741ms/step
# 1/1 [==============================] - 1s 1000ms/step
# 1/1 [==============================] - 1s 952ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 700ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 970ms/step
# 1/1 [==============================] - 1s 944ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 850ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 788ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 842ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 906ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 750ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 580ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 932ms/step
# 1/1 [==============================] - 1s 994ms/step
# 1/1 [==============================] - 1s 972ms/step
# 1/1 [==============================] - 1s 760ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 577ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 843ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 909ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 628ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 575ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 578ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 990ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 910ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 581ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 811ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 945ms/step
# 1/1 [==============================] - 1s 851ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 846ms/step
# 1/1 [==============================] - 1s 922ms/step
# ...
# 1/1 [==============================] - 1s 887ms/step
# 1/1 [==============================] - 1s 622ms/step
# 1/1 [==============================] - 1s 618ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 579ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 804ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 960ms/step
# 1/1 [==============================] - 1s 856ms/step
# 1/1 [==============================] - 1s 623ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 616ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 936ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 908ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 962ms/step
# 1/1 [==============================] - 1s 766ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 615ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 595ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 978ms/step
# 1/1 [==============================] - 1s 959ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 987ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 583ms/step
# 1/1 [==============================] - 1s 605ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 587ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 983ms/step
# 1/1 [==============================] - 1s 967ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 619ms/step
# 1/1 [==============================] - 1s 615ms/step
# 1/1 [==============================] - 1s 940ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 629ms/step
# 1/1 [==============================] - 1s 596ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 615ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 931ms/step
# 1/1 [==============================] - 1s 997ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 763ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 589ms/step
# 1/1 [==============================] - 1s 606ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 627ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 591ms/step
# 1/1 [==============================] - 1s 588ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 645ms/step
# 1/1 [==============================] - 1s 978ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 952ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 592ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 584ms/step
# 1/1 [==============================] - 1s 604ms/step
# 1/1 [==============================] - 1s 620ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 617ms/step
# 1/1 [==============================] - 1s 971ms/step
# 1/1 [==============================] - 1s 992ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 910ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 618ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 598ms/step
# 1/1 [==============================] - 1s 594ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 975ms/step
# 1/1 [==============================] - 1s 956ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 754ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 1s 607ms/step
# 1/1 [==============================] - 1s 600ms/step
# 1/1 [==============================] - 1s 616ms/step
# 1/1 [==============================] - 1s 603ms/step
# 1/1 [==============================] - 1s 621ms/step
# 1/1 [==============================] - 1s 614ms/step
# 1/1 [==============================] - 1s 639ms/step
# 1/1 [==============================] - 1s 593ms/step
# 1/1 [==============================] - 1s 590ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 609ms/step
# 1/1 [==============================] - 1s 726ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 951ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 646ms/step
# 1/1 [==============================] - 1s 610ms/step
# 1/1 [==============================] - 1s 601ms/step
# 1/1 [==============================] - 1s 586ms/step
# 1/1 [==============================] - 1s 613ms/step
# 1/1 [==============================] - 1s 620ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 626ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 582ms/step
# 1/1 [==============================] - 1s 599ms/step
# 1/1 [==============================] - 1s 608ms/step
# 1/1 [==============================] - 1s 597ms/step
# 1/1 [==============================] - 1s 591ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-7a1d6a8b4c37> in <cell line: 2>()
#       5     img = (img / 255.).astype(np.float32)
#       6     img = cv2.resize(img, dsize = (224,224))
# ----> 7     embedding_vector = vgg_face_descriptor.predict(np.expand_dims(img, axis=0))[0]
#       8     embeddings[i]=embedding_vector
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2653                     for step in data_handler.steps():
#    2654                         callbacks.on_predict_batch_begin(step)
# -> 2655                         tmp_batch_outputs = self.predict_function(iterator)
#    2656                         if data_handler.should_sync:
#    2657                             context.async_wait()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     830
#     831       with OptionalXlaContext(self._jit_compile):
# --> 832         result = self._call(*args, **kwds)
#     833
#     834       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     875       # In this case we have not created variables on the first call. So we can
#     876       # run the first trace but we should fail if variables are created.
# --> 877       results = tracing_compilation.call_function(
#     878           args, kwds, self._variable_creation_config
#     879       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1321         and executing_eagerly):
#    1322       # No tape is watching; skip to running the function.
# -> 1323       return self._inference_function.call_preflattened(args)
#    1324     forward_backward = self._select_forward_and_backward_functions(
#    1325         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1484     cancellation_context = cancellation.context()
#    1485     if cancellation_context is None:
# -> 1486       outputs = execute.execute(
#    1487           name.decode("utf-8"),
#    1488           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
print('embeddings shape :', embeddings.shape)

# %%
embeddings[0], embeddings[988], embeddings[988].shape

# %%
embeddings[8275]

# %% [markdown]
# <p style = "font-size:20px; color: #007580 "><strong> Function to calculate distance between given 2 pairs of images </strong></p>
#
# - Consider distance metric as "Squared L2 distance"
# - Squared l2 distance between 2 points (x1, y1) and (x2, y2) = (x1-x2)^2 + (y1-y2)^2

# %%
def distance(emb1, emb2):
    return np.sum(np.square(emb1 - emb2))

# %% [markdown]
# <a id = '4.3'></a>
# <p style = "font-size:20px; color: #007580 "><strong>9. Plot images and get distance between the pairs </strong></p>
#
# - 900, 901 and 900, 1001
# - 1100, 1101 and 1100, 1300
# - 1407, 1408 and 1408, 1602

# %%
def show_pair(idx1, idx2):
    plt.figure(figsize=(8,3))
    plt.suptitle(f'Distance between {idx1} & {idx2}= {distance(embeddings[idx1], embeddings[idx2]):.2f}')
    plt.subplot(121)
    plt.imshow(load_image(metadata[idx1].image_path()))
    plt.subplot(122)
    plt.imshow(load_image(metadata[idx2].image_path()));

show_pair(900, 901)
show_pair(900, 1001)

# %%
show_pair(1100, 1101)
show_pair(1100, 1300)

# %%
show_pair(1407, 1408)
show_pair(1408, 1602)

# %% [markdown]
# <a id = '4.4'></a>
# <p style = "font-size:20px; color: #007580 "><strong> 10.Create train and test sets </strong></p>
# - Create X_train, X_test and y_train, y_test
# - Use train_idx to seperate out training features and labels
# - Use test_idx to seperate out testing features and labels

# %%
train_idx = np.arange(metadata.shape[0]) % 9 != 0
test_idx = np.arange(metadata.shape[0]) % 9 == 0

# one half as train examples of 10 identities
X_train = embeddings[train_idx]

# another half as test examples of 10 identities
X_test = embeddings[test_idx]
targets = np.array([m.name for m in metadata])

#train labels
y_train = targets[train_idx]

#test labels
y_test = targets[test_idx]

# %%
print('X_train shape : ({0},{1})'.format(X_train.shape[0], X_train.shape[1]))
print('y_train shape : ({0},)'.format(y_train.shape[0]))
print('X_test shape : ({0},{1})'.format(X_test.shape[0], X_test.shape[1]))
print('y_test shape : ({0},)'.format(y_test.shape[0]))
# Out:
# X_train shape : (15585,2622)
# y_train shape : (15585,)
# X_test shape : (1949,2622)
# y_test shape : (1949,)

# %%
y_test[0], y_train[988]
# Out:
# ('pins_Henry Cavil', 'pins_Maria Pedraza')

# %%
len(np.unique(y_test)), len(np.unique(y_train))
# Out:
# (105, 105)

# %% [markdown]
# <p style = "font-size:20px; color: #007580 "><strong>11. Encode the Labels </strong></p>
# - Encode the targets
# - Use LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_train_encoded = le.fit_transform(y_train)

# %%
print(le.classes_)
y_test_encoded = le.transform(y_test)
# Out:
# ['pins_Adriana Lima' 'pins_Alex Lawther' 'pins_Alexandra Daddario'
#  'pins_Alvaro Morte' 'pins_Amanda Crew' 'pins_Andy Samberg'
#  'pins_Anne Hathaway' 'pins_Anthony Mackie' 'pins_Avril Lavigne'
#  'pins_Ben Affleck' 'pins_Bill Gates' 'pins_Bobby Morley'
#  'pins_Brenton Thwaites' 'pins_Brian J. Smith' 'pins_Brie Larson'
#  'pins_Chris Evans' 'pins_Chris Hemsworth' 'pins_Chris Pratt'
#  'pins_Christian Bale' 'pins_Cristiano Ronaldo' 'pins_Danielle Panabaker'
#  'pins_Dominic Purcell' 'pins_Dwayne Johnson' 'pins_Eliza Taylor'
#  'pins_Elizabeth Lail' 'pins_Emilia Clarke' 'pins_Emma Stone'
#  'pins_Emma Watson' 'pins_Gwyneth Paltrow' 'pins_Henry Cavil'
#  'pins_Hugh Jackman' 'pins_Inbar Lavi' 'pins_Irina Shayk'
#  'pins_Jake Mcdorman' 'pins_Jason Momoa' 'pins_Jennifer Lawrence'
#  'pins_Jeremy Renner' 'pins_Jessica Barden' 'pins_Jimmy Fallon'
#  'pins_Johnny Depp' 'pins_Josh Radnor' 'pins_Katharine Mcphee'
#  'pins_Katherine Langford' 'pins_Keanu Reeves' 'pins_Krysten Ritter'
#  'pins_Leonardo DiCaprio' 'pins_Lili Reinhart' 'pins_Lindsey Morgan'
#  'pins_Lionel Messi' 'pins_Logan Lerman' 'pins_Madelaine Petsch'
#  'pins_Maisie Williams' 'pins_Maria Pedraza' 'pins_Marie Avgeropoulos'
#  'pins_Mark Ruffalo' 'pins_Mark Zuckerberg' 'pins_Megan Fox'
#  'pins_Miley Cyrus' 'pins_Millie Bobby Brown' 'pins_Morena Baccarin'
#  'pins_Morgan Freeman' 'pins_Nadia Hilker' 'pins_Natalie Dormer'
#  'pins_Natalie Portman' 'pins_Neil Patrick Harris' 'pins_Pedro Alonso'
#  'pins_Penn Badgley' 'pins_Rami Malek' 'pins_Rebecca Ferguson'
#  'pins_Richard Harmon' 'pins_Rihanna' 'pins_Robert De Niro'
#  'pins_Robert Downey Jr' 'pins_Sarah Wayne Callies' 'pins_Selena Gomez'
#  'pins_Shakira Isabel Mebarak' 'pins_Sophie Turner' 'pins_Stephen Amell'
#  'pins_Taylor Swift' 'pins_Tom Cruise' 'pins_Tom Hardy'
#  'pins_Tom Hiddleston' 'pins_Tom Holland' 'pins_Tuppence Middleton'
#  'pins_Ursula Corbero' 'pins_Wentworth Miller' 'pins_Zac Efron'
#  'pins_Zendaya' 'pins_Zoe Saldana' 'pins_alycia dabnem carey'
#  'pins_amber heard' 'pins_barack obama' 'pins_barbara palvin'
#  'pins_camila mendes' 'pins_elizabeth olsen' 'pins_ellen page'
#  'pins_elon musk' 'pins_gal gadot' 'pins_grant gustin' 'pins_jeff bezos'
#  'pins_kiernen shipka' 'pins_margot robbie' 'pins_melissa fumero'
#  'pins_scarlett johansson' 'pins_tom ellis']

# %%
print('y_train_encoded : ', y_train_encoded)
print('y_test_encoded : ', y_test_encoded)
# Out:
# y_train_encoded :  [29 29 29 ... 84 84 84]
# y_test_encoded :  [29 29 29 ... 84 84 84]

# %% [markdown]
# <p style = "font-size:20px; color: #007580 "><strong> 12.Standardize the feature values </strong></p>
# - Scale the features using StandardScaler

# %%
# Standarize features
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)

# %%
X_test_std = scaler.transform(X_test)

# %% [markdown]
# <a id = '4.5'></a>
# <p style = "font-size:20px; color: #007580 "><strong> 13.Reduce dimensions using PCA </strong></p>
# - Reduce feature dimensions using Principal Component Analysis
# - Set the parameter n_components=128

# %%
print('X_train_std shape : ({0},{1})'.format(X_train_std.shape[0], X_train_std.shape[1]))
print('y_train_encoded shape : ({0},)'.format(y_train_encoded.shape[0]))
print('X_test_std shape : ({0},{1})'.format(X_test_std.shape[0], X_test_std.shape[1]))
print('y_test_encoded shape : ({0},)'.format(y_test_encoded.shape[0]))
# Out:
# X_train_std shape : (15585,2622)
# y_train_encoded shape : (15585,)
# X_test_std shape : (1949,2622)
# y_test_encoded shape : (1949,)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=128)
X_train_pca = pca.fit_transform(X_train_std)
X_test_pca = pca.transform(X_test_std)

# %% [markdown]
# <a id = '5.0'></a>
# <h2 style = "font-size:35px; font-family:Garamond ; font-weight : normal; background-color: #007580; color :#fed049   ; text-align: center; border-radius: 5px 5px; padding: 5px"> Model Building and Validation </h2>

# %% [markdown]
# <a id = '5.1'></a>
# # <p style = "font-size:20px; color: #007580 "><strong> 14. Build a Machine Learning Classifier </strong></p>
#
# - Use SVM Classifier to predict the person in the given image
# - Fit the classifier and print the score

# %%
from sklearn.svm import SVC

clf = SVC(C=5., gamma=0.001)
clf.fit(X_train_pca, y_train_encoded)
# Out:
# SVC(C=5.0, gamma=0.001)

# %%
y_predict = clf.predict(X_test_pca)

# %%
print('y_predict : ',y_predict)
print('y_test_encoded : ',y_test_encoded)
# Out:
# y_predict :  [29 29 29 ...  2  2  2]
# y_test_encoded :  [29 29 29 ... 84 84 84]

# %%
y_predict_encoded = le.inverse_transform(y_predict)

# %%
print('y_predict_encoded : ',y_predict_encoded)
# Out:
# y_predict_encoded :  ['pins_Henry Cavil' 'pins_Henry Cavil' 'pins_Henry Cavil' ...
#  'pins_Alexandra Daddario' 'pins_Alexandra Daddario'
#  'pins_Alexandra Daddario']

# %%
print('y_predict shape : ', y_predict.shape)
print('y_test_encoded shape : ', y_test_encoded.shape)
# Out:
# y_predict shape :  (1949,)
# y_test_encoded shape :  (1949,)

# %%
y_test_encoded[32:49]
# Out:
# array([ 1,  1,  1,  1,  1,  1,  1, 63, 63, 63, 63, 63, 63, 63, 63, 63, 63])

# %%
# Find the classification accuracy
accuracy_score(y_test_encoded, y_predict)
# Out:
# 0.6459722934838379

# %% [markdown]
# **Accuracy Score: 96.455%**

# %% [markdown]
# <a id = '5.2'></a>
# <p style = "font-size:20px; color: #007580 "><strong> Validate Celebrity Images </strong></p>
#
# - Take  401th  image from test set and plot the image
# - Report to which person(folder name in dataset) the image belongs to

# %%
example_idx = 401

example_image = load_image(metadata[test_idx][example_idx].image_path())
example_prediction = y_predict[example_idx]
example_identity =  y_predict_encoded[example_idx]

plt.imshow(example_image)
plt.title(f'Identified as {example_identity}');

# %%
example_idx = 900

example_image = load_image(metadata[test_idx][example_idx].image_path())
example_prediction = y_predict[example_idx]
example_identity =  y_predict_encoded[example_idx]

plt.imshow(example_image)
plt.title(f'Identified as {example_identity}');

# %%
example_idx = 317

example_image = load_image(metadata[test_idx][example_idx].image_path())
example_prediction = y_predict[example_idx]
example_identity =  y_predict_encoded[example_idx]

plt.imshow(example_image)
plt.title(f'Identified as {example_identity}');

# %%
example_idx = -27

example_image = load_image(metadata[test_idx][example_idx].image_path())
example_prediction = y_predict[example_idx]
example_identity =  y_predict_encoded[example_idx]

plt.imshow(example_image)
plt.title(f'Identified as {example_identity}');
